# %%
import requests

# %%
import json

# %% [markdown]
# user inputs movie title

# %%
movie_title = input("Enter the Movie title: ")
# Out:
# Enter the Movie title: Game of throne

# %% [markdown]
# Constructing the URL with the key included

# %%
api_key = '26b4544f'

# %%
url = f'http://www.omdbapi.com/?i={movie_title}&apikey={api_key}'

# %% [markdown]
# Sending the request to the API and storing response

# %%
response = requests.get(url)

# %%
try:
    response = requests.get(url)
    response.raise_for_status()
    movie_data = response.json()

    if 'Error' in movie_data:
        raise ValueError("No data found for the movie title provided.")
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except requests.exceptions.ConnectionError as conn_err:
    print(f"Connection error occurred: {conn_err}")
except requests.exceptions.RequestException as req_err:
    print(f"An error occurred: {req_err}")
except ValueError as ve:
    print(ve)
else:
    print("Movie data retrieved successfully!")
# Out:
# No data found for the movie title provided.

# %%
if 'movie_data' in locals():
    title = movie_data.get('Title', 'N/A')
    year = movie_data.get('Year', 'N/A')
    director = movie_data.get('Director', 'N/A')
    #store the extracted information in a dictionary
    movie_info = {
        'Title': title,
        'Tear': year,
        'Director': director
    }
    #Display the extracted movie information
    print(movie_info)
# Out:
# {'Title': 'N/A', 'Tear': 'N/A', 'Director': 'N/A'}

# %% [markdown]
# Storing Data in a File

# %%
with open('movie_info.txt', 'w') as file:
    #Write the movie information to the text file in JSON format
    file.write(json.dumps(movie_info, indent=4))

# %% [markdown]
# Reading and displaying Stored Data

# %%
def displayed_stored_movie_info():
    try:
        #Open and read thr stored movie info from the file
        with open('movie_info.txt', 'r') as file:
            stored_data = json.load(file)
            print("Stored Movie Information:")
            #print the stored data in a readable JSON format
            print(json.dumps(stored_data, indent=4))
    except FileNotFoundError:
        print("This file does not exist.")
    except json.JSONDecodeError:
        print("Error decoding the JSON data.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
#call the function to display the stored movie information
displayed_stored_movie_info()
# Out:
# Stored Movie Information:
# {
#     "Title": "N/A",
#     "Tear": "N/A",
#     "Director": "N/A"
# }
